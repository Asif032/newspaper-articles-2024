# %%
import pandas as pd

# %%
df = pd.read_json('mzamin_news_articles.jsonl', lines=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45450 entries, 0 to 45449
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date_published  45098 non-null  object
#  1   date_modified   45098 non-null  object
#  2   author          45098 non-null  object
#  3   category        45098 non-null  object
#  4   tag             45450 non-null  object
#  5   title           45098 non-null  object
#  6   url             45450 non-null  object
#  7   content         45098 non-null  object
# dtypes: object(8)
# memory usage: 2.8+ MB

# %%
df.head()
# Out:
#              date_published             date_modified           author  \
# 0  ১ জানুয়ারি ২০২৪, সোমবার  ১ জানুয়ারি ২০২৪, সোমবার  স্টাফ রিপোর্টার
# 1  ১ জানুয়ারি ২০২৪, সোমবার  ১ জানুয়ারি ২০২৪, সোমবার  স্টাফ রিপোর্টার
# 2  ১ জানুয়ারি ২০২৪, সোমবার  ১ জানুয়ারি ২০২৪, সোমবার  স্টাফ রিপোর্টার
# 3  ১ জানুয়ারি ২০২৪, সোমবার  ১ জানুয়ারি ২০২৪, সোমবার  স্টাফ রিপোর্টার
# 4  ১ জানুয়ারি ২০২৪, সোমবার  ১ জানুয়ারি ২০২৪, সোমবার  স্টাফ রিপোর্টার
#
#     category tag                                              title  \
# 0  দেশ বিদেশ  []  ৯ মামলায় মির্জা ফখরুলের জামিন শুনানি নির্বাচনে...
# 1  দেশ বিদেশ  []  ৯ মামলায় মির্জা ফখরুলের জামিন শুনানি নির্বাচনে...
# 2  দেশ বিদেশ  []  ৯ মামলায় মির্জা ফখরুলের জামিন শুনানি নির্বাচনে...
# 3  দেশ বিদেশ  []  ৯ মামলায় মির্জা ফখরুলের জামিন শুনানি নির্বাচনে...
# 4  দেশ বিদেশ  []  ৯ মামলায় মির্জা ফখরুলের জামিন শুনানি নির্বাচনে...
#
#                                       url  \
# 0  https://mzamin.com/news.php?news=90903
# 1  https://mzamin.com/news.php?news=90903
# 2  https://mzamin.com/news.php?news=90903
# 3  https://mzamin.com/news.php?news=90903
# 4  https://mzamin.com/news.php?news=90903
#
#                                              content
# 0  এজাহারনামীয় আসামি হলেও গ্রেপ্তার না দেখানো ৯ট...
# 1  এজাহারনামীয় আসামি হলেও গ্রেপ্তার না দেখানো ৯ট...
# 2  এজাহারনামীয় আসামি হলেও গ্রেপ্তার না দেখানো ৯ট...
# 3  এজাহারনামীয় আসামি হলেও গ্রেপ্তার না দেখানো ৯ট...
# 4  এজাহারনামীয় আসামি হলেও গ্রেপ্তার না দেখানো ৯ট...

# %%
length_counts = df['date_published'].astype(str).apply(len).value_counts()
print(length_counts)
# Out:
# date_published
# 21    4448
# 23    3840
# 25    2880
# 26    2640
# 22    2576
# 47    2208
# 20    2096
# 52    2000
# 27    1920
# 24    1824
# 51    1690
# 18    1616
# 48    1472
# 49    1408
# 53    1312
# 54    1200
# 28    1168
# 50    1088
# 19    1088
# 46    1072
# 55     832
# 44     704
# 45     512
# 29     512
# 57     496
# 17     496
# 31     480
# 56     416
# 4      352
# 30     336
# 58     208
# 32     208
# 43     144
# 60     128
# 59      64
# 61      16
# Name: count, dtype: int64

# %%
filtered_df = df[df['category'] == 'ভিডিও']
print(len(filtered_df))
filtered_df
# Out:
# 0
# Empty DataFrame
# Columns: [date_published, date_modified, author, category, tag, title, url, content]
# Index: []

# %%
sorted_df = df.sort_values(by='url', ascending=True)
sorted_df.reset_index(drop=True)
sorted_df
df = sorted_df

# %%
df.head()
# Out:
#             date_published         date_modified                       author  \
# 9117  ৩ মার্চ ২০২৪, রবিবার  ৩ মার্চ ২০২৪, রবিবার  স্টাফ রিপোর্টার, সিলেট থেকে
# 9116  ৩ মার্চ ২০২৪, রবিবার  ৩ মার্চ ২০২৪, রবিবার  স্টাফ রিপোর্টার, সিলেট থেকে
# 9115  ৩ মার্চ ২০২৪, রবিবার  ৩ মার্চ ২০২৪, রবিবার  স্টাফ রিপোর্টার, সিলেট থেকে
# 9114  ৩ মার্চ ২০২৪, রবিবার  ৩ মার্চ ২০২৪, রবিবার  স্টাফ রিপোর্টার, সিলেট থেকে
# 9113  ৩ মার্চ ২০২৪, রবিবার  ৩ মার্চ ২০২৪, রবিবার  স্টাফ রিপোর্টার, সিলেট থেকে
#
#         category tag                                          title  \
# 9117  বাংলারজমিন  []  সিলেট মহানগর জামায়াতের বিক্ষোভ মিছিল ও সমাবেশ
# 9116  বাংলারজমিন  []  সিলেট মহানগর জামায়াতের বিক্ষোভ মিছিল ও সমাবেশ
# 9115  বাংলারজমিন  []  সিলেট মহানগর জামায়াতের বিক্ষোভ মিছিল ও সমাবেশ
# 9114  বাংলারজমিন  []  সিলেট মহানগর জামায়াতের বিক্ষোভ মিছিল ও সমাবেশ
# 9113  বাংলারজমিন  []  সিলেট মহানগর জামায়াতের বিক্ষোভ মিছিল ও সমাবেশ
#
#                                           url  \
# 9117  https://mzamin.com/news.php?news=100007
# 9116  https://mzamin.com/news.php?news=100007
# 9115  https://mzamin.com/news.php?news=100007
# 9114  https://mzamin.com/news.php?news=100007
# 9113  https://mzamin.com/news.php?news=100007
#
#                                                 content
# 9117  সিলেট মহানগর জামায়াত নেতৃবৃন্দ বলেছেন, জনগণের...
# 9116  সিলেট মহানগর জামায়াত নেতৃবৃন্দ বলেছেন, জনগণের...
# 9115  সিলেট মহানগর জামায়াত নেতৃবৃন্দ বলেছেন, জনগণের...
# 9114  সিলেট মহানগর জামায়াত নেতৃবৃন্দ বলেছেন, জনগণের...
# 9113  সিলেট মহানগর জামায়াত নেতৃবৃন্দ বলেছেন, জনগণের...

# %%
df.to_csv('mzamin_news_articles.csv', index=False)
