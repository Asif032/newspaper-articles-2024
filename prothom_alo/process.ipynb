# %%
import pandas as pd

# %%
df = pd.read_json('prothom_alo_news_articles.jsonl', lines=True)

# %%
df.head()
# Out:
#         date_published        date_modified            author    category  \
# 0  2024-01-02T01:17:55  2024-01-02T01:17:55         প্রতিনিধি        জেলা
# 1  2024-01-01T23:55:00  2024-01-01T23:55:00         প্রতিনিধি       বলিউড
# 2  2024-01-01T23:45:00  2024-01-01T23:45:00  বিনোদন প্রতিবেদক        নাটক
# 3  2024-01-02T03:19:34  2024-01-02T03:19:34  নিজস্ব প্রতিবেদক        জেলা
# 4  2024-01-01T23:06:32  2024-01-01T23:06:32              None  অনলাইন ভোট
#
#                                                  tag  \
# 0  [শ্রীপুর, গাজীপুর, ঢাকা বিভাগ, স্বতন্ত্র প্রার...
# 1               [অভিনয় শিল্পী, হিন্দি সিনেমা, তারকা]
# 2      [মঞ্চ নাটক, সংস্কৃতি, শিল্পকলা একাডেমি, মঞ্চ]
# 3  [ব্রাহ্মণবাড়িয়া, বিজয়নগর, চট্টগ্রাম বিভাগ, স্ব...
# 4                                  [জনমত-জরিপ, জরিপ]
#
#                                                title  \
# 0  স্বতন্ত্র প্রার্থীর নির্বাচনী কার্যালয়ের পাশে...
# 1                            ‘বলিউডে টিকে থাকা কঠিন’
# ...

# %%
df['date_published'] = pd.to_datetime(df['date_published'])
df['date_modified'] = pd.to_datetime(df['date_modified'])
df.head()
# Out:
#        date_published       date_modified            author    category  \
# 0 2024-01-02 01:17:55 2024-01-02 01:17:55         প্রতিনিধি        জেলা
# 1 2024-01-01 23:55:00 2024-01-01 23:55:00         প্রতিনিধি       বলিউড
# 2 2024-01-01 23:45:00 2024-01-01 23:45:00  বিনোদন প্রতিবেদক        নাটক
# 3 2024-01-02 03:19:34 2024-01-02 03:19:34  নিজস্ব প্রতিবেদক        জেলা
# 4 2024-01-01 23:06:32 2024-01-01 23:06:32              None  অনলাইন ভোট
#
#                                                  tag  \
# 0  [শ্রীপুর, গাজীপুর, ঢাকা বিভাগ, স্বতন্ত্র প্রার...
# 1               [অভিনয় শিল্পী, হিন্দি সিনেমা, তারকা]
# 2      [মঞ্চ নাটক, সংস্কৃতি, শিল্পকলা একাডেমি, মঞ্চ]
# 3  [ব্রাহ্মণবাড়িয়া, বিজয়নগর, চট্টগ্রাম বিভাগ, স্ব...
# 4                                  [জনমত-জরিপ, জরিপ]
#
#                                                title  \
# 0  স্বতন্ত্র প্রার্থীর নির্বাচনী কার্যালয়ের পাশে...
# 1                            ‘বলিউডে টিকে থাকা কঠিন’
# ...

# %%
df = df.sort_values(by='date_published', ascending=True)
df.head()
# Out:
#          date_published       date_modified            author    category  \
# 215 2024-01-01 07:00:00 2024-01-01 07:00:00        খেলা ডেস্ক        খেলা
# 220 2024-01-01 07:00:00 2024-01-01 07:00:00             লেখা:       মতামত
# 217 2024-01-01 07:01:00 2024-01-01 07:01:00   বিশেষ প্রতিবেদক  উচ্চশিক্ষা
# 214 2024-01-01 07:32:47 2024-01-01 07:32:47   প্রথম আলো ডেস্ক    বাংলাদেশ
# 216 2024-01-01 08:00:00 2024-01-01 08:00:00  জাহিদ হোসাইন খান     বিজ্ঞান
#
#                                                    tag  \
# 215                                 [আজকের খেলা, টিভি]
# 220                [পাঠকের লেখা, যুদ্ধ, ইংরেজি নববর্ষ]
# 217  [বই, শিক্ষাপ্রতিষ্ঠান, শিক্ষা, প্রাথমিক ও মাধ্...
# 214  [আজকের পত্রিকা, মামলা, সংঘর্ষ, দ্বাদশ সংসদ নির...
# 216                          [জাপান, রোবট, অগ্নিকাণ্ড]
#
#                                                  title  \
# 215              আজ টিভিতে যা দেখবেন (১ জানুয়ারি ২০২৪)
# 220      নতুন বছর এবং বিশ্ববাসীর কিছু পুরোনো প্রত্যাশা
# ...

# %%
df.to_csv('prothom_alo_news_articles.csv', index=False)

# %%
df.head()
# Out:
#          date_published       date_modified            author    category  \
# 215 2024-01-01 07:00:00 2024-01-01 07:00:00        খেলা ডেস্ক        খেলা
# 220 2024-01-01 07:00:00 2024-01-01 07:00:00             লেখা:       মতামত
# 217 2024-01-01 07:01:00 2024-01-01 07:01:00   বিশেষ প্রতিবেদক  উচ্চশিক্ষা
# 214 2024-01-01 07:32:47 2024-01-01 07:32:47   প্রথম আলো ডেস্ক    বাংলাদেশ
# 216 2024-01-01 08:00:00 2024-01-01 08:00:00  জাহিদ হোসাইন খান     বিজ্ঞান
#
#                                                    tag  \
# 215                                 [আজকের খেলা, টিভি]
# 220                [পাঠকের লেখা, যুদ্ধ, ইংরেজি নববর্ষ]
# 217  [বই, শিক্ষাপ্রতিষ্ঠান, শিক্ষা, প্রাথমিক ও মাধ্...
# 214  [আজকের পত্রিকা, মামলা, সংঘর্ষ, দ্বাদশ সংসদ নির...
# 216                          [জাপান, রোবট, অগ্নিকাণ্ড]
#
#                                                  title  \
# 215              আজ টিভিতে যা দেখবেন (১ জানুয়ারি ২০২৪)
# 220      নতুন বছর এবং বিশ্ববাসীর কিছু পুরোনো প্রত্যাশা
# ...
