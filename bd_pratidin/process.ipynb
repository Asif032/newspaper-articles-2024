# %%
import pandas as pd

# %%
df = pd.read_json('bd_pratidin_news_articles.jsonl', lines=True)

# %%
df.head()
# Out:
#         date_published        date_modified             author  \
# 0  2024-01-01T00:00:00  2024-01-01T00:00:00   নিজস্ব প্রতিবেদক
# 1  2024-01-01T00:00:00  2024-01-01T00:00:00   নিজস্ব প্রতিবেদক
# 2  2024-01-01T00:00:00  2024-01-01T00:00:00     প্রতিদিন ডেস্ক
# 3  2024-01-01T00:00:00  2024-01-01T00:00:00    সাখাওয়াত কাওসার
# 4  2024-01-01T00:00:00  2024-01-01T00:00:00  ঝিনাইদহ প্রতিনিধি
#
#           category                                                tag  \
# 0        last-page  [প্রার্থিতা, বাতিল, সালাউদ্দিনের, লাখ, টাকা, জ...
# 1        last-page  [নানা, আয়োজনে, থার্টিফার্স্ট, নাইট, রাজধানী, হ...
# 2  country-village                      [তরুণী, মাটিচাপা, লাশ উদ্ধার]
# 3        last-page                 [বিশেষ, অভিযানে, কাটছে, না, শঙ্কা]
# 4  country-village            [অস্ত্র ও গুলি, যুবক গ্রেফতার, ঝিনাইদহ]
#
#                                               title  \
# 0  প্রার্থিতা বাতিল  সালাউদ্দিনের, লাখ টাকা জরিমানা
# 1                    নানা আয়োজনে থার্টিফার্স্ট নাইট
# ...

# %%
df['date_published'] = pd.to_datetime(df['date_published'])
df['date_modified'] = pd.to_datetime(df['date_modified'])
df.head()
# Out:
#      date_published date_modified               author         category  \
# 0        2024-01-01    2024-01-01     নিজস্ব প্রতিবেদক        last-page
# 6850     2024-01-01    2024-01-01   কুমিল্লা প্রতিনিধি  country-village
# 6851     2024-01-01    2024-01-01   দিনাজপুর প্রতিনিধি  country-village
# 6852     2024-01-01    2024-01-01  সিরাজগঞ্জ প্রতিনিধি  country-village
# 7395     2024-01-01    2024-01-01          Not defined       technology
#
#                                                     tag  \
# 0     [প্রার্থিতা, বাতিল, সালাউদ্দিনের, লাখ, টাকা, জ...
# 6850            [ফলদ ও বনজ, গাছ কেটে ফেলল, দুর্বৃত্তরা]
# 6851                   [চিকিৎসকদের, বিক্ষোভ, মানববন্ধন]
# 6852                 [যাবজ্জীবন, সাজার আসামি, গ্রেফতার]
# 7395                 [চমকপ্রদ, ফিচার আনছে, হোয়াটসঅ্যাপ]
#
#                                                  title  \
# 0     প্রার্থিতা বাতিল  সালাউদ্দিনের, লাখ টাকা জরিমানা
# 6850               ফলদ ও বনজ গাছ কেটে ফেলল দুর্বৃত্তরা
# ...

# %%
df = df.sort_values(by='date_published', ascending=True)
df.tail()
# Out:
#       date_published       date_modified                       author  \
# 96368     2024-11-18 2024-11-18 18:17:05  ফুলপুর (ময়মনসিংহ) প্রতিনিধি
# 96429     2024-11-18 2024-11-18 20:22:51                 অনলাইন ডেস্ক
# 96392     2024-11-18 2024-11-18 19:02:52               রাবি প্রতিনিধি
# 96306     2024-11-18 2024-11-18 15:06:04            গাজীপুর প্রতিনিধি
# 96334     2024-11-18 2024-11-18 16:35:19                 সিলেট ব্যুরো
#
#             category                                                tag  \
# 96368        country                                                 []
# 96429       national             [বিসিএস, মৌখিক, পরীক্ষা, বাতিল, ভাইভা]
# 96392  campus-online            [রাবি, ফুটবল খেলা, সংঘর্ষ, শিক্ষক, আহত]
# 96306        country                                                 []
# 96334       national  [প্রাথমিক, পাঠ্যবই, পরিবর্তন, গণশিক্ষা, উপদেষ্টা]
#
#                                                    title  \
# ...

# %%
df.to_csv('bd_pratidin_news_articles.csv', index=False)
