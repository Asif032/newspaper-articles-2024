# %%
import pandas as pd

# %%
df = pd.read_csv('ittefaq_news_articles.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33657 entries, 0 to 33656
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      33657 non-null  int64
#  1   date_published  33656 non-null  object
#  2   date_modified   33656 non-null  object
#  3   author          33657 non-null  object
#  4   category        33656 non-null  object
#  5   tag             32400 non-null  object
#  6   title           33656 non-null  object
#  7   url             33657 non-null  object
#  8   content         33656 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                     date_published  \
# 0           0  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৮:০০
# 1           1  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৬:০০
# 2           2  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৪:০০
# 3           3  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০১:৫৬
# 4           4  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৫:০০
#
#                       date_modified                author category  \
# 0  আপডেট : ০১ জানুয়ারি ২০২৪, ০৮:০০                    []   শিক্ষা
# 1  আপডেট : ০১ জানুয়ারি ২০২৪, ০৯:৫৭  ["ইত্তেফাক রিপোর্ট"]    জাতীয়
# 2  আপডেট : ০১ জানুয়ারি ২০২৪, ০৪:০০  ["ইত্তেফাক রিপোর্ট"]   শিক্ষা
# 3  আপডেট : ০১ জানুয়ারি ২০২৪, ০১:৫৬  ["ইত্তেফাক রিপোর্ট"]  রাজনীতি
# 4  আপডেট : ০১ জানুয়ারি ২০২৪, ০৫:০০  ["ইত্তেফাক রিপোর্ট"]  বাণিজ্য
#
#                                         tag  \
# 0               ["বিশেষ সংবাদ", "বই ‍উৎসব"]
# 1     ["ঋণ", "বাংলাদেশ ব্যাংক", "নতুন বছর"]
# 2  ["প্রাথমিক শিক্ষা", "প্রাথমিক বিদ্যালয়"]
# 3                     ["জাতীয় পার্টি-জেপি"]
# ...

# %%
length_counts = df['date_published'].astype(str).apply(len).value_counts()
print(length_counts)
# Out:
# date_published
# 29    9504
# 31    4703
# 34    3495
# 33    3482
# 26    3299
# 35    3267
# 30    2977
# 27    2796
# 32      34
# 36      27
# 38      25
# 40      23
# 39      23
# 37       1
# 3        1
# Name: count, dtype: int64

# %%
filtered_df = df[df['date_published'].str.contains('পিএম', na=False)]
print(len(filtered_df))
filtered_df = df[df['date_published'].str.contains('এএম', na=False)]
print(len(filtered_df))
filtered_df
# Out:
# 237
# 6
#        Unnamed: 0                         date_published  \
# 767           775  প্রকাশ : ০৭ জানুয়ারি ২০২৪, ১০:০০ এএম
# 8609         8671      প্রকাশ : ১৭ মার্চ ২০২৪, ১১:৪৩ এএম
# 17014       17138        প্রকাশ : ০৬ জুন ২০২৪, ১১:৫৭ এএম
# 18106       18242        প্রকাশ : ১৭ জুন ২০২৪, ১১:৪০ এএম
# 29270       29561    প্রকাশ : ০৪ অক্টোবর ২০২৪, ০৪:৫০ এএম
# 29288       29581    প্রকাশ : ০৪ অক্টোবর ২০২৪, ১১:১৪ এএম
#
#                                date_modified                      author  \
# 767    আপডেট : ০৭ জানুয়ারি ২০২৪, ০১:৪৩ পিএম   ["ইত্তেফাক অনলাইন ডেস্ক"]
# 8609       আপডেট : ১৭ মার্চ ২০২৪, ০৪:৩৫ পিএম   ["ইত্তেফাক অনলাইন ডেস্ক"]
# 17014         আপডেট : ০৬ জুন ২০২৪, ১১:৫৭ এএম  ["ইত্তেফাক ডিজিটাল ডেস্ক"]
# 18106         আপডেট : ১৭ জুন ২০২৪, ১১:৪০ এএম  ["ইত্তেফাক ডিজিটাল ডেস্ক"]
# 29270     আপডেট : ০৪ অক্টোবর ২০২৪, ০৫:০৮ এএম  ["ইত্তেফাক ডিজিটাল ডেস্ক"]
# 29288     আপডেট : ০৪ অক্টোবর ২০২৪, ১১:১৪ এএম   ["ইত্তেফাক অনলাইন ডেস্ক"]
#
# ...

# %%
filtered_df = df[df['category'] == 'ভিডিও']
print(len(filtered_df))
filtered_df
# Out:
# 0
# Empty DataFrame
# Columns: [Unnamed: 0, date_published, date_modified, author, category, tag, title, url, content]
# Index: []

# %%
sorted_df = df.sort_values(by='url', ascending=True)
sorted_df.reset_index(drop=True)
sorted_df
df = sorted_df

# %%
df = df[df['category'] != 'ভিডিও']
df
# Out:
#        Unnamed: 0                     date_published  \
# 0               0  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৮:০০
# 1               1  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৬:০০
# 2               2  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৪:০০
# 3               3  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০১:৫৬
# 4               4  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৫:০০
# ...           ...                                ...
# 33652       33991    প্রকাশ : ১২ নভেম্বর ২০২৪, ১৭:০৮
# 33653       33992    প্রকাশ : ১২ নভেম্বর ২০২৪, ১৭:১০
# 33654       33993    প্রকাশ : ১২ নভেম্বর ২০২৪, ১৭:১৬
# 33655       33994    প্রকাশ : ১২ নভেম্বর ২০২৪, ১৭:২৩
# 33656       33995    প্রকাশ : ১২ নভেম্বর ২০২৪, ১৭:৩৯
#
#                           date_modified                       author  \
# 0      আপডেট : ০১ জানুয়ারি ২০২৪, ০৮:০০                           []
# 1      আপডেট : ০১ জানুয়ারি ২০২৪, ০৯:৫৭         ["ইত্তেফাক রিপোর্ট"]
# 2      আপডেট : ০১ জানুয়ারি ২০২৪, ০৪:০০         ["ইত্তেফাক রিপোর্ট"]
# ...

# %%
filtered_df = df[df['url'] >= 'https://www.ittefaq.com.bd/695000']

# %%
df.head()
# Out:
#    Unnamed: 0                     date_published  \
# 0           0  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৮:০০
# 1           1  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৬:০০
# 2           2  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৪:০০
# 3           3  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০১:৫৬
# 4           4  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৫:০০
#
#                       date_modified                author category  \
# 0  আপডেট : ০১ জানুয়ারি ২০২৪, ০৮:০০                    []   শিক্ষা
# 1  আপডেট : ০১ জানুয়ারি ২০২৪, ০৯:৫৭  ["ইত্তেফাক রিপোর্ট"]    জাতীয়
# 2  আপডেট : ০১ জানুয়ারি ২০২৪, ০৪:০০  ["ইত্তেফাক রিপোর্ট"]   শিক্ষা
# 3  আপডেট : ০১ জানুয়ারি ২০২৪, ০১:৫৬  ["ইত্তেফাক রিপোর্ট"]  রাজনীতি
# 4  আপডেট : ০১ জানুয়ারি ২০২৪, ০৫:০০  ["ইত্তেফাক রিপোর্ট"]  বাণিজ্য
#
#                                         tag  \
# 0               ["বিশেষ সংবাদ", "বই ‍উৎসব"]
# 1     ["ঋণ", "বাংলাদেশ ব্যাংক", "নতুন বছর"]
# 2  ["প্রাথমিক শিক্ষা", "প্রাথমিক বিদ্যালয়"]
# 3                     ["জাতীয় পার্টি-জেপি"]
# ...

# %%
# Drop the 'Unnamed' column if it exists
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# Save it back to the same file without the index
df.to_csv("ittefaq_news_article.csv", index=False)

# %%
df.head()
# Out:
#                       date_published                     date_modified  \
# 0  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৮:০০  আপডেট : ০১ জানুয়ারি ২০২৪, ০৮:০০
# 1  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৬:০০  আপডেট : ০১ জানুয়ারি ২০২৪, ০৯:৫৭
# 2  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৪:০০  আপডেট : ০১ জানুয়ারি ২০২৪, ০৪:০০
# 3  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০১:৫৬  আপডেট : ০১ জানুয়ারি ২০২৪, ০১:৫৬
# 4  প্রকাশ : ০১ জানুয়ারি ২০২৪, ০৫:০০  আপডেট : ০১ জানুয়ারি ২০২৪, ০৫:০০
#
#                  author category                                       tag  \
# 0                    []   শিক্ষা               ["বিশেষ সংবাদ", "বই ‍উৎসব"]
# 1  ["ইত্তেফাক রিপোর্ট"]    জাতীয়     ["ঋণ", "বাংলাদেশ ব্যাংক", "নতুন বছর"]
# 2  ["ইত্তেফাক রিপোর্ট"]   শিক্ষা  ["প্রাথমিক শিক্ষা", "প্রাথমিক বিদ্যালয়"]
# 3  ["ইত্তেফাক রিপোর্ট"]  রাজনীতি                     ["জাতীয় পার্টি-জেপি"]
# 4  ["ইত্তেফাক রিপোর্ট"]  বাণিজ্য                          ["স্বর্ণালংকার"]
#
#                                      title                                url  \
# ...

# %%
df.to_csv('ittefaq_news_articles.csv', index=False)

# %%
filtered_df = df.loc[df['url'] >= 'https://www.ittefaq.com.bd/695726', ['date_published']]
filtered_df[:5]
# Out:
#                       date_published
# 22836  প্রকাশ : ০৭ আগস্ট ২০২৪, ২০:৪৫
# 22837  প্রকাশ : ০৭ আগস্ট ২০২৪, ২০:৪৭
# 22838  প্রকাশ : ০৭ আগস্ট ২০২৪, ২১:১২
# 22839  প্রকাশ : ০৭ আগস্ট ২০২৪, ২১:১৮
# 22840  প্রকাশ : ০৭ আগস্ট ২০২৪, ২১:১৯

# %%
base_url = 'https://www.ittefaq.com.bd/'
num = 10
