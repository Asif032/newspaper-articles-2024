# %%
import pandas as pd

# %%
df = pd.read_json('bhorerkagoj_news_articles.jsonl', lines=True)

# %%
df.head()
# Out:
#         date_published        date_modified                      author  \
# 0  2024-01-01T21:37:54  2024-01-01T00:00:00              স্পোর্টস ডেস্ক
# 1  2024-01-01T21:37:54  2024-01-01T00:00:00                  কাগজ ডেস্ক
# 2  2024-01-01T21:37:54  2024-01-01T21:44:48              কাগজ প্রতিবেদক
# 3  2024-01-01T21:37:54  2024-01-01T23:01:22  মেঘনা (কুমিল্লা) প্রতিনিধি
# 4  2024-01-01T21:37:54  2024-01-01T21:50:47              কাগজ প্রতিবেদক
#
#       category                                                tag  \
# 0         খেলা                                                 []
# 1  আন্তর্জাতিক                                  [ভূমিকম্প, জাপান]
# 2     অর্থনীতি               [ব্যাংক-বন্ধু, ৭ জানুয়ারি, নির্বাচন]
# 3      সারাদেশ  [কুমিল্লা, যুবক, কারাদণ্ড, ভ্রাম্যমাণ আদালত, চ...
# 4      রাজনীতি        [রাজনীতি, রাজধানী, নৌকা, আওয়ামী লীগ, নাছিম]
#
#                                                title  \
# 0                         গোল তালিকার শীর্ষে রোনালদো
# ...

# %%
df['date_published'] = pd.to_datetime(df['date_published'])
df['date_modified'] = pd.to_datetime(df['date_modified'])
df.head()
# Out:
#        date_published       date_modified                      author  \
# 0 2024-01-01 21:37:54 2024-01-01 00:00:00              স্পোর্টস ডেস্ক
# 1 2024-01-01 21:37:54 2024-01-01 00:00:00                  কাগজ ডেস্ক
# 2 2024-01-01 21:37:54 2024-01-01 21:44:48              কাগজ প্রতিবেদক
# 3 2024-01-01 21:37:54 2024-01-01 23:01:22  মেঘনা (কুমিল্লা) প্রতিনিধি
# 4 2024-01-01 21:37:54 2024-01-01 21:50:47              কাগজ প্রতিবেদক
#
#       category                                                tag  \
# 0         খেলা                                                 []
# 1  আন্তর্জাতিক                                  [ভূমিকম্প, জাপান]
# 2     অর্থনীতি               [ব্যাংক-বন্ধু, ৭ জানুয়ারি, নির্বাচন]
# 3      সারাদেশ  [কুমিল্লা, যুবক, কারাদণ্ড, ভ্রাম্যমাণ আদালত, চ...
# 4      রাজনীতি        [রাজনীতি, রাজধানী, নৌকা, আওয়ামী লীগ, নাছিম]
#
#                                                title  \
# 0                         গোল তালিকার শীর্ষে রোনালদো
# ...

# %%
df = df.sort_values(by='date_published', ascending=True)
df.head()
# Out:
#     date_published date_modified author category tag  \
# 110     2024-01-01    2024-01-01   None      খবর  []
# 97      2024-01-01    2024-01-01   None      খবর  []
# 98      2024-01-01    2024-01-01   None      খবর  []
# 99      2024-01-01    2024-01-01   None      খবর  []
# 100     2024-01-01    2024-01-01   None  সারাদেশ  []
#
#                                                  title  \
# 110  এমফিল-পিএইচডি প্রোগ্রাম : বিইউপিতে পরিচিতিমূলক...
# 97                        ইমরান খানের মনোনয়নপত্র বাতিল
# 98          রিজার্ভ চুরির তদন্ত প্রতিবেদন পেছাল ৭৬ বার
# 99                     ভারতের মনিপুরে ফের সংঘাত নিহত ১
# 100  দুর্গাপূজায় নাশকতা করতে চেয়েছিল জঙ্গিরা, গ্রেপ...
#
#                                             url content
# 110  https://www.bhorerkagoj.com/tp-news/395743
# 97   https://www.bhorerkagoj.com/tp-news/395756
# 98   https://www.bhorerkagoj.com/tp-news/395750
# 99   https://www.bhorerkagoj.com/tp-news/395755
# 100  https://www.bhorerkagoj.com/country/395758

# %%
df.to_csv('bhorerkagoj_news_articles.csv', index=False)
